# %% [markdown]
# # Modellazione dataset con Graphlab

# %%
import graphlab

# %% [markdown]
# # Carico un DATASET

# %%
# Scommentare la riga sotto per caricare il dataset
#
#sf = graphlab.SFrame.read_csv("data/kc_house_data.csv")

# %%
sf.tail()
# Out:
# Columns:
# 	id	int
# 	date	str
# 	price	float
# 	bedrooms	int
# 	bathrooms	float
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	int
# 	lat	float
# 	long	float
# 	sqft_living15	int
# 	sqft_lot15	int
#
# Rows: 10
#
# Data:
# +------------+-----------------+-----------+----------+-----------+-------------+
# |     id     |       date      |   price   | bedrooms | bathrooms | sqft_living |
# +------------+-----------------+-----------+----------+-----------+-------------+
# | 7852140040 | 20140825T000000 |  507250.0 |    3     |    2.5    |     2270    |
# | 9834201367 | 20150126T000000 |  429000.0 |    3     |    2.0    |     1490    |
# | 3448900210 | 20141014T000000 |  610685.0 |    4     |    2.5    |     2520    |
# | 7936000429 | 20150326T000000 | 1007500.0 |    4     |    3.5    |     3510    |
# ...

# %%
sfm = sf['id','price','sqft_lot','zipcode']

# %%
sfm.sort('price', ascending=False)
# Out:
# Columns:
# 	id	int
# 	price	float
# 	sqft_lot	int
# 	zipcode	int
#
# Rows: 21613
#
# Data:
# +------------+-----------+----------+---------+
# |     id     |   price   | sqft_lot | zipcode |
# +------------+-----------+----------+---------+
# | 6762700020 | 7700000.0 |  27600   |  98102  |
# | 9808700762 | 7062500.0 |  37325   |  98004  |
# | 9208900037 | 6885000.0 |  31374   |  98039  |
# | 2470100110 | 5570000.0 |  35069   |  98039  |
# | 8907500070 | 5350000.0 |  23985   |  98004  |
# | 7558700030 | 5300000.0 |  24829   |  98040  |
# | 1247600105 | 5110800.0 |  45517   |  98033  |
# | 1924059029 | 4668000.0 |  13068   |  98040  |
# | 7738500731 | 4500000.0 |  40014   |  98155  |
# | 3835500195 | 4489000.0 |  27517   |  98004  |
# +------------+-----------+----------+---------+
# [21613 rows x 4 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
sfmM = sfm.groupby('zipcode',{'price2zipcode': graphlab.aggregate.SUM('price')},{'num': graphlab.aggregate.COUNT('id')},{'avg' : graphlab.aggregate.AVG('price')})

# %%
sfmM.head()
# Out:
# Columns:
# 	zipcode	int
# 	price2zipcode	float
# 	num	int
# 	avg	float
#
# Rows: 10
#
# Data:
# +---------+---------------+-----+---------------+
# | zipcode | price2zipcode | num |      avg      |
# +---------+---------------+-----+---------------+
# |  98115  |  361402019.0  | 583 |  619900.54717 |
# |  98118  |  212159816.0  | 508 | 417637.433071 |
# |  98014  |   56496522.0  | 124 | 455617.112903 |
# |  98023  |  143079663.0  | 499 | 286732.791583 |
# |  98105  |  197586978.0  | 229 | 862825.231441 |
# |  98059  |  230982585.0  | 468 | 493552.532051 |
# |  98019  |   80709862.0  | 190 | 424788.747368 |
# |  98109  |   95878975.0  | 109 | 879623.623853 |
# |  98107  |  154028209.0  | 266 | 579053.417293 |
# |  98178  |   81380542.0  | 262 | 310612.755725 |
# +---------+---------------+-----+---------------+
# [10 rows x 4 columns]

# %%
sfmM.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:49343/index.html
# Opening Canvas in default web browser.
